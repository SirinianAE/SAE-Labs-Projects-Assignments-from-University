# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Matrix multiplication running times (16 jobs)')
plt.plot([1, 2, 3, 4, 8, 16], [4.297909, 2.16247425, 1.639735, 1.1651907499999998, 1.18433, 1.189985])
plt.plot([1, 2, 3, 4, 8, 16], [4.297909, 2.16247425, 1.639735, 1.1651907499999998, 1.18433, 1.189985], 'bo')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Matrix multiplication running times (256 jobs)')
plt.plot([1, 2, 3, 4, 8, 16], [5.692215999999999, 2.1621697500000003, 1.6287465, 1.0900905, 1.0836302500000001, 0.9822982499999999])
plt.plot([1, 2, 3, 4, 8, 16], [5.692215999999999, 2.1621697500000003, 1.6287465, 1.0900905, 1.0836302500000001, 0.9822982499999999], 'bo')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Matrix multiplication running times (1024 jobs)')
plt.plot([1, 2, 3, 4, 8, 16], [4.613384, 2.2975835, 1.6879167499999999, 1.15796375, 1.369931, 1.2600985])
plt.plot([1, 2, 3, 4, 8, 16], [4.613384, 2.2975835, 1.6879167499999999, 1.15796375, 1.369931, 1.2600985], 'bo')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot([1, 2, 3, 4, 8, 16], [4.297909, 2.16247425, 1.639735, 1.1651907499999998, 1.18433, 1.189985])
plt.plot([1, 2, 3, 4, 8, 16], [5.692215999999999, 2.1621697500000003, 1.6287465, 1.0900905, 1.0836302500000001, 0.9822982499999999])
plt.plot([1, 2, 3, 4, 8, 16], [4.613384, 2.2975835, 1.6879167499999999, 1.15796375, 1.369931, 1.2600985])

plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Matrix multiplication running times')
plt.legend(("16 jobs", "256 jobs", "1024 jobs"), loc=0)

plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Βarrier implementation')
plt.plot([1, 2, 3, 4, 8, 16], [3.56990225, 1.7866184999999999, 1.2334225, 0.956996, 0.9539129999999999, 0.9684847499999999])
plt.plot([1, 2, 3, 4, 8, 16], [3.56990225, 1.7866184999999999, 1.2334225, 0.956996, 0.9539129999999999, 0.9684847499999999], 'bo')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Pthread barrier')
plt.plot([1, 2, 3, 4, 8, 16], [3.594846, 1.8107989999999998, 1.24859775, 0.969241, 0.95085825, 0.9429702499999999])
plt.plot([1, 2, 3, 4, 8, 16], [3.594846, 1.8107989999999998, 1.24859775, 0.969241, 0.95085825, 0.9429702499999999], 'bo')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Barrier implementation (#consecutive barrier waits: 1000)')
plt.plot([1, 2, 3, 4, 8, 16], [3.572386, 1.7915234999999998, 1.2394382499999999, 0.9674490000000001, 1.004491, 1.0669745])
plt.plot([1, 2, 3, 4, 8, 16], [3.572386, 1.7915234999999998, 1.2394382499999999, 0.9674490000000001, 1.004491, 1.0669745], 'bo')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('Pthread barrier (#consecutive barrier waits: 1000)')
plt.plot([1, 2, 3, 4, 8, 16], [3.5903424999999998, 1.8094407499999998, 1.8201345, 1.257675, 0.9787425000000001, 1.020408])
plt.plot([1, 2, 3, 4, 8, 16], [3.5903424999999998, 1.8094407499999998, 1.8201345, 1.257675, 0.9787425000000001, 1.020408], 'bo')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot([1, 2, 3, 4, 8, 16], [3.56990225, 1.7866184999999999, 1.2334225, 0.956996, 0.9539129999999999, 0.9684847499999999])
plt.plot([1, 2, 3, 4, 8, 16], [3.594846, 1.8107989999999998, 1.24859775, 0.969241, 0.95085825, 0.9429702499999999])
plt.plot([1, 2, 3, 4, 8, 16], [3.572386, 1.7915234999999998, 1.2394382499999999, 0.9674490000000001, 1.004491, 1.0669745])
plt.plot([1, 2, 3, 4, 8, 16], [3.5903424999999998, 1.8094407499999998, 1.8201345, 1.257675, 0.9787425000000001, 1.020408])


plt.xlabel('# Threads')
plt.ylabel('Time (sec)')
plt.title('All barrier related runs')
plt.legend(('Βarrier implementation', 'Pthread barrier', 'Barrier implementation (#consecutive barrier waits: 1000)', 'Pthread barrier (#consecutive barrier waits: 1000)'), loc=0)

plt.show()
